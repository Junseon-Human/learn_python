# %%
import re
# 기초
# 1. 숫자(0~9)로만 구성된 문자열을 한 자리 이상 검증하시오.
# ^[0-9]+$

# 2. 영문 소문자(a~z)로만 구성된 문자열을 한 자리 이상 검증하시오.
# ^[a-z]+$

# 3. 영문 대문자(A~Z)로만 구성된 문자열을 한 자리 이상 검증하시오.
# ^[A-Z]+$

# 4. 영문 알파벳(대소문자)로만 구성된 문자열을 한 자리 이상 검증하시오.
# ^[a-zA-Z]+$

# 5. 정확히 3자리 숫자인지 검증하시오.
# ^\d+${3}

# 6. 전화번호 형식(지역번호 2자리)-(중간 4자리)-(마지막 4자리)를 검증하시오.
# "\d{2}-\d{4}-\d{4}"

# 7. 한글 이름이 2~4글자인지 검증하시오.
# "[가-힣]{2,4}"

# 8. 문자열이 ab로 시작하는지 검증하시오.
# "^ab"

# 9. 문자열 내 공백문자(스페이스, 탭 등)를 찾는 정규식을 작성하시오.
# \s

# 10. 문자열 안에 apple이라는 단어가 포함되어 있는지 찾으시오.
# apple

# %%
# 중급
# 11. 이메일 형식을 검증하시오. (예: 유저명@도메인.확장자)

# 12. http:// 또는 https://로 시작하는 URL을 검증하시오.

# 13. 주민등록번호(앞 6자리-뒷 7자리)를 검증하시오.

# 14. 한글이 2~5글자인지 검증하시오.

# 15. 문자열이 start로 시작하고 end로 끝나는지 검증하시오.

# 16. 전체 문자열이 임의 문자로 5~10자리인지 검증하시오.

# 17. 영어 대소문자와 숫자로만 구성된 아이디(4~12자리)를 검증하시오.

# 18. HTML 태그를 찾는 정규식을 작성하시오.

# 19. 문자열 내 전화번호(국번-번호)를 추출하시오.

# 20. 날짜 형식(YYYY-MM-DD)을 검증하시오.

# %%
# 고급
# 21. 대문자, 소문자, 숫자를 각각 1개 이상 포함하는 문자열을 Lookahead로 검증하시오.

# 22. $ 기호 뒤에 오는 숫자만 추출하기 위해 Lookbehind를 사용하시오.

# 23. 이메일 주소를 username과 domain 그룹으로 나눠서 캡처하시오.

# 24. http:// 또는 https://를 선택적으로 허용하는 URL 정규식을 작성하시오.

# 25. 처음 3자리가 000이면 매칭되지 않도록 하시오.

# 26. 숫자로 시작하면 4자리 숫자, 아니면 4자리 영문을 매칭하시오.

# 27. HTML 태그 중 id 속성을 가진 태그만 매칭하시오.

# 28. 이메일 주소 전체 길이를 6~30자로 제한하시오.

# 29. 다국어 문자열 중 한글만 추출하시오.

# 30. 한글, 영문, 숫자만 허용하는 정규식을 작성하시오.

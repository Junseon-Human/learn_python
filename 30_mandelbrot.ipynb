# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\main\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\main\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\main\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\main\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\main\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\main\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\main\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\main\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\main\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\main\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\main\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# matplotlib.pyplot 는 데이터를 시각화 할때 많이 쓰임 주로 그래프나 차트를 그림

import matplotlib.pyplot as plt


# 윈도우 기준 - 'Malgun Gothic'
plt.rcParams["font.family"] = "Malgun Gothic"

# 마이너스 깨짐 방지
plt.rcParams["axes.unicode_minus"] = False

x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

plt.plot(x, y)
plt.title("선 그래프 예시")
plt.xlabel("X축")
plt.ylabel("Y축")
plt.grid(True)
plt.show()

labels = ["A", "B", "C", "D"]
values = [10, 20, 15, 25]

plt.bar(labels, values)
plt.title("막대 그래프 예시")
plt.show()

x = [1, 2, 3, 4, 5]
y = [2, 1, 4, 3, 7]

plt.scatter(x, y)
plt.title("산점도 예시")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

labels = ["Apple", "Banana", "Cherry", "Date"]
sizes = [30, 25, 25, 20]

plt.pie(sizes, labels=labels, autopct="%1.1f%%")
plt.title("파이 차트 예시")
plt.axis("equal")  # 원 모양으로 만들기
plt.show()

# %%
data = np.random.randn(10000)
plt.hist(data, bins=10)
plt.show()

# %%
data = np.random.randint(-100, 100, 10000)
plt.hist(data, bins=10)
plt.show()
